# %%
# !sudo apt-get install python3.x
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-xstatic-dagre-d3' for regex 'python3.x'
# Note, selecting 'python3-xstatic-spin' for regex 'python3.x'
# Note, selecting 'python3-xgboost' for regex 'python3.x'
# Note, selecting 'python3-xstatic-jasmine' for regex 'python3.x'
# Note, selecting 'python3-xmlsec' for regex 'python3.x'
# Note, selecting 'python3-xlsxwriter' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular-fileupload' for regex 'python3.x'
# Note, selecting 'python3-xstatic-magic-search' for regex 'python3.x'
# Note, selecting 'python3-xstatic-jquery-migrate' for regex 'python3.x'
# Note, selecting 'python3-xstatic-moment' for regex 'python3.x'
# Note, selecting 'python3-xstatic-font-awesome' for regex 'python3.x'
# Note, selecting 'python3-xstatic-dagre' for regex 'python3.x'
# Note, selecting 'python3-xattr' for regex 'python3.x'
# Note, selecting 'python3-xeddsa' for regex 'python3.x'
# Note, selecting 'python3-xhtml2pdf' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular-vis' for regex 'python3.x'
# Note, selecting 'python3-xmlrunner' for regex 'python3.x'
# Note, selecting 'python3-x2go' for regex 'python3.x'
# Note, selecting 'python3-x3dh' for regex 'python3.x'
# Note, selecting 'python3-xstatic-bootstrap-datepicker' for regex 'python3.x'
# Note, selecting 'python3-xstatic-jsencrypt' for regex 'python3.x'
# Note, selecting 'python3-xstatic-objectpath' for regex 'python3.x'
# Note, selecting 'python3-xrayutilities' for regex 'python3.x'
# Note, selecting 'python3-xstatic-qunit' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular-schema-form' for regex 'python3.x'
# Note, selecting 'python3-xmltodict' for regex 'python3.x'
# Note, selecting 'python3-xstatic-json2yaml' for regex 'python3.x'
# Note, selecting 'python3-xstatic-term.js' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular-bootstrap' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular-uuid' for regex 'python3.x'
# Note, selecting 'python3-xstatic-mdi' for regex 'python3.x'
# Note, selecting 'python3-xapian' for regex 'python3.x'
# Note, selecting 'python3-xclarityclient' for regex 'python3.x'
# Note, selecting 'python3-xstatic-tv4' for regex 'python3.x'
# Note, selecting 'python3-xphyle' for regex 'python3.x'
# Note, selecting 'python3-xstatic-graphlib' for regex 'python3.x'
# Note, selecting 'python3-xstatic-lodash' for regex 'python3.x'
# Note, selecting 'python3-xrstools' for regex 'python3.x'
# Note, selecting 'python3-xmodem' for regex 'python3.x'
# Note, selecting 'python3-xstatic-d3' for regex 'python3.x'
# Note, selecting 'python3-xapp' for regex 'python3.x'
# Note, selecting 'python3-xdmf' for regex 'python3.x'
# Note, selecting 'python3-xapian-haystack' for regex 'python3.x'
# Note, selecting 'python3-xcffib' for regex 'python3.x'
# Note, selecting 'python3-xstatic-jquery' for regex 'python3.x'
# Note, selecting 'python3-xxhash' for regex 'python3.x'
# Note, selecting 'python3-xstatic-jquery.quicksearch' for regex 'python3.x'
# Note, selecting 'python3-xkcd' for regex 'python3.x'
# Note, selecting 'python3-xkit' for regex 'python3.x'
# Note, selecting 'python3-xlib' for regex 'python3.x'
# Note, selecting 'python3-xlrd' for regex 'python3.x'
# Note, selecting 'python3-xlwt' for regex 'python3.x'
# Note, selecting 'python3-xmlschema' for regex 'python3.x'
# Note, selecting 'python3-xstatic-roboto-fontface' for regex 'python3.x'
# Note, selecting 'python3-xstatic-bootstrap-scss' for regex 'python3.x'
# Note, selecting 'python3-xstatic-bootswatch' for regex 'python3.x'
# Note, selecting 'python3-xstatic-jquery.bootstrap.wizard' for regex 'python3.x'
# Note, selecting 'python3-xstatic' for regex 'python3.x'
# Note, selecting 'python3-xsdata' for regex 'python3.x'
# Note, selecting 'python3-xmmsclient' for regex 'python3.x'
# Note, selecting 'python3-xdg' for regex 'python3.x'
# Note, selecting 'python3-xdo' for regex 'python3.x'
# Note, selecting 'python3-xstatic-filesaver' for regex 'python3.x'
# Note, selecting 'python3-xstatic-smart-table' for regex 'python3.x'
# Note, selecting 'python3-x2gobroker' for regex 'python3.x'
# Note, selecting 'python3-xrootd' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular-ui-router' for regex 'python3.x'
# Note, selecting 'python3-xarray' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular-gettext' for regex 'python3.x'
# Note, selecting 'python3-xopen' for regex 'python3.x'
# Note, selecting 'python3-xtermcolor' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular-lrdragndrop' for regex 'python3.x'
# Note, selecting 'python3-xstatic-rickshaw' for regex 'python3.x'
# Note, selecting 'python3-xstatic-js-yaml' for regex 'python3.x'
# Note, selecting 'python3-xcbgen' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular-mock' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular' for regex 'python3.x'
# Note, selecting 'python3-xstatic-hogan' for regex 'python3.x'
# Note, selecting 'python3-xstatic-jquery-ui' for regex 'python3.x'
# Note, selecting 'python3-xstatic-angular-cookies' for regex 'python3.x'
# Note, selecting 'python3-xvfbwrapper' for regex 'python3.x'
# Note, selecting 'python3-xstatic-jquery.tablesorter' for regex 'python3.x'
# Note, selecting 'python3-xstatic-moment-timezone' for regex 'python3.x'
# The following additional packages will be installed:
#   avahi-daemon bind9-host bind9-libs binfmt-support clang-11 cups-bsd
#   cups-client cups-common fonts-dejavu-core fonts-font-awesome
#   fonts-glyphicons-halflings fonts-lato fonts-lyx
#   fonts-materialdesignicons-webfont fonts-mathjax fonts-roboto-fontface
#   fonts-urw-base35 freeglut3 fuse3 geoclue-2.0 glib-networking
#   glib-networking-common glib-networking-services gsettings-desktop-schemas
#   ieee-data iio-sensor-proxy javascript-common libasound2-plugins
#   libavahi-core7 libavahi-glib1 libc-ares2 libclang-common-11-dev
#   libclang-cpp11 libclang1-11 libdaemon0 libdmlc0 libev4 libevdev2 libffi-dev
#   libfftw3-single3 libfontenc1 libfuse3-3 libglu1-mesa libgudev-1.0-0
#   libhdf5-openmpi-103-1 libhyphen0 libimagequant0 libinput-bin libinput10
#   libjs-angular-file-upload libjs-angular-gettext libjs-angular-schema-form
#   libjs-angularjs libjs-angularjs-smart-table libjs-bootstrap libjs-bootswatch
#   libjs-d3 libjs-jquery-metadata libjs-jquery-tablesorter
#   libjs-jquery.quicksearch libjs-jsencrypt libjs-lrdragndrop
#   libjs-magic-search libjs-mathjax libjs-objectpath libjs-qunit libjs-rickshaw
#   libjs-spin.js libjs-term.js libjs-tv4 libjs-twitter-bootstrap-datepicker
#   libjs-twitter-bootstrap-wizard libjson-glib-1.0-0 libjson-glib-1.0-common
#   liblbfgsb0 libllvm11 liblmdb0 liblzf1 liblzo2-2 libmaxminddb0 libmbim-glib4
#   libmbim-proxy libmd4c0 libmm-glib0 libmtdev1 libnl-genl-3-200 libnotify4
#   libnss-mdns libpfm4 libpocl2 libpocl2-common libproxy1v5 libpulsedsp
#   libqmi-glib5 libqmi-proxy libqt5core5a libqt5dbus5 libqt5designer5
#   libqt5gui5 libqt5help5 libqt5location5 libqt5multimedia5
#   libqt5multimediawidgets5 libqt5network5 libqt5opengl5 libqt5positioning5
#   libqt5positioningquick5 libqt5printsupport5 libqt5qml5 libqt5qmlmodels5
#   libqt5quick5 libqt5quickwidgets5 libqt5sensors5 libqt5serialport5 libqt5sql5
#   libqt5sql5-sqlite libqt5svg5 libqt5test5 libqt5texttospeech5
#   libqt5webchannel5 libqt5webengine-data libqt5webengine5 libqt5webenginecore5
#   libqt5webenginewidgets5 libqt5webkit5 libqt5websockets5 libqt5widgets5
#   libqt5xml5 libqt5xmlpatterns5 libraqm0 libre2-9 libsnapd-glib1 libsoup2.4-1
#   libsoup2.4-common libspeechd2 libspeexdsp1 libsvm3 libtdb1 libtinyxml2.6.2v5
#   libudev1 libwacom-bin libwacom-common libwacom9 libwebrtc-audio-processing1
#   libwoff1 libwrap0 libxapian30 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcomp3 libxdmf3 libxdo3 libxfont2 libxgboost0 libxkbcommon-x11-0
#   libxkbfile1 libxmlsec1 libxmlsec1-openssl libxmmsclient6 libxrdcl3
#   libxrdcrypto2 libxrdcryptolite2 libxrdutils3 libxrdxml3 libxsimd-dev
#   libxtst6 libz3-4 libz3-dev llvm-11 llvm-11-dev llvm-11-linker-tools
#   llvm-11-runtime llvm-11-tools mailcap mime-support modemmanager numba-doc
#   nxproxy pigz pocl-opencl-icd pulseaudio pulseaudio-utils pymca-data
#   python-babel-localedata python-fisx-common python-mako-doc
#   python-matplotlib-data python-numpy-doc python-odf-doc python-odf-tools
#   python-pyopencl-doc python-tables-data python-xrayutilities-doc
#   python3-appdirs python3-asciitree python3-asgiref python3-asteval
#   python3-attr python3-babel python3-backcall python3-bcrypt python3-beniget
#   python3-blosc python3-bottleneck python3-brotli python3-bs4 python3-certifi
#   python3-cffi python3-cftime python3-chardet python3-click
#   python3-cloudpickle python3-colorama python3-cycler python3-daemon
#   python3-dask python3-dateutil python3-decorator python3-defusedxml
#   python3-distributed python3-django python3-django-haystack python3-doc
#   python3-dropbox python3-elementpath python3-entrypoints python3-et-xmlfile
#   python3-fabio python3-fasteners python3-fisx python3-fonttools python3-fs
#   python3-fsspec python3-fusepy python3-future python3-gast python3-gevent
#   python3-greenlet python3-h5netcdf python3-h5py python3-h5py-serial
#   python3-heapdict python3-html5lib python3-idna python3-iniconfig
#   python3-ipykernel python3-ipython python3-ipython-genutils python3-jdcal
#   python3-jedi python3-jinja2 python3-joblib python3-jupyter-client
#   python3-jupyter-core python3-kiwisolver python3-libarchive-c python3-libsvm
#   python3-llvmlite python3-lmfit python3-locket python3-lockfile python3-lxml
#   python3-lz4 python3-mako python3-markupsafe python3-matplotlib
#   python3-matplotlib-inline python3-mdp python3-mock python3-monotonic
#   python3-mpmath python3-msgpack python3-nacl python3-nest-asyncio
#   python3-netaddr python3-netcdf4 python3-nose python3-numba python3-numcodecs
#   python3-numexpr python3-numpy python3-odf python3-olefile python3-opengl
#   python3-openpyxl python3-packaging python3-pampy python3-pandas
#   python3-pandas-lib python3-paramiko python3-parso python3-partd python3-pbr
#   python3-pexpect python3-pickleshare python3-pil python3-pil.imagetk
#   python3-pip python3-platformdirs python3-pluggy python3-ply python3-pokrok
#   python3-prompt-toolkit python3-psutil python3-ptyprocess python3-py
#   python3-pycparser python3-pygit2 python3-pygments python3-pymca5
#   python3-pyopencl python3-pypdf2 python3-pyqt5 python3-pyqt5.qtmultimedia
#   python3-pyqt5.qtopengl python3-pyqt5.qtpositioning python3-pyqt5.qtquick
#   python3-pyqt5.qtsensors python3-pyqt5.qtserialport python3-pyqt5.qtsql
#   python3-pyqt5.qtsvg python3-pyqt5.qttexttospeech python3-pyqt5.qtwebchannel
#   python3-pyqt5.qtwebengine python3-pyqt5.qtwebkit python3-pyqt5.qtwebsockets
#   python3-pyqt5.qtxmlpatterns python3-pyqt5.sip python3-pytest python3-pythran
#   python3-pytools python3-qtconsole python3-qtpy python3-renderpm
#   python3-reportlab python3-reportlab-accel python3-requests python3-scipy
#   python3-setuptools python3-silx python3-simplejson python3-sklearn
#   python3-sklearn-lib python3-sortedcontainers python3-soupsieve
#   python3-sqlparse python3-stone python3-sympy python3-tables
#   python3-tables-lib python3-tblib python3-threadpoolctl python3-toml
#   python3-toolz python3-tornado python3-traitlets python3-tz python3-ufolib2
#   python3-uncertainties python3-unicodedata2 python3-urllib3 python3-wcwidth
#   python3-webencodings python3-wheel python3-yaml python3-zarr python3-zict
#   python3-zmq python3-zope.event python3-zope.interface python3.10-doc
#   qt5-gtk-platformtheme qtspeech5-speechd-plugin qttranslations5-l10n rtkit
#   session-migration sphinx-rtd-theme-common sshfs systemd-hwe-hwdb udev
#   unicode-data usb-modeswitch usb-modeswitch-data wpasupplicant x11-xkb-utils
#   x2gobroker-common xfonts-base xfonts-encodings xfonts-utils
#   xrootd-client-plugins xrootd-plugins xserver-common xvfb
# Suggested packages:
#   avahi-autoipd clang-11-doc cups inetutils-inetd | inet-superserver
#   update-inetd smbclient fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   apache2 | lighttpd | httpd libfftw3-bin libfftw3-dev fonts-mathjax-extras
#   fonts-stix libjs-mathjax-doc mmdb-bin gnome-shell | notification-daemon
#   avahi-autoipd | zeroconf qt5-image-formats-plugins qtwayland5
#   qt5-qmltooling-plugins snapd xapian-tools libxsimd-doc llvm-11-doc pavumeter
#   pavucontrol paprefs ubuntu-sounds python-attr-doc python-blosc-doc
#   python-bottleneck-doc python-cycler-doc ipython python-dask-doc
#   python3-bcolz python3-boto python3-graphviz python3-skimage
#   python3-sqlalchemy bpython3 geoip-database-contrib gettext ipython3
#   libgdal20 libsqlite3-mod-spatialite python-django-doc python3-flup
#   python3-pymemcache | python3-pylibmc python3-mysqldb python3-psycopg2
#   python3-selenium python3-sqlite python3-elasticsearch python3-whoosh
#   python3-examples python-fabio-doc python-fsspec-doc python-future-doc
#   python-gevent-doc python3-openssl python-greenlet-dev python-greenlet-doc
#   python-h5py-doc python3-genshi python-ipython-doc python-jinja2-doc
#   llvmlite-doc python-lmfit-doc python-lockfile-doc python-lxml-doc
#   python3-beaker dvipng fonts-staypuft ghostscript gir1.2-gtk-3.0 inkscape
#   librsvg2-common python-matplotlib-doc python3-cairocffi python3-gi-cairo
#   python3-gobject python3-sip texlive-extra-utils texlive-latex-extra
#   python-mock-doc python-mpmath-doc python3-gmpy2 python-nacl-doc
#   python-netaddr-docs python-nose-doc nvidia-cuda-toolkit www-browser libgle3
#   python-pandas-doc python3-statsmodels python3-gssapi python3-invoke
#   python-pexpect-doc python-pil-doc python-ply-doc python-psutil-doc
#   subversion python-pygit2-doc python-pygments-doc ttf-bitstream-vera
#   python3-imaging-tk pdf-viewer python3-egenix-mxtexttools
#   python-reportlab-doc python3-socks python-requests-doc python-scipy-doc
#   python-setuptools-doc python3-dap python-sklearn-doc
#   python-sortedcontainers-doc python-sqlparse-doc texlive-fonts-extra
#   python-sympy-doc python-tables-doc vitables python-toolz-doc python3-pycurl
#   python-tornado-doc python3-twisted python-uncertainties-doc
#   telekinesis-client mteleplayer-clientside xapian-doc python-xarray-doc
#   python3-cartopy python3-pydap python3-rasterio python3-seaborn
#   python-xkcd-doc python-xlrt-doc python-xrstools-doc python3-tango
#   python-xsdata-doc jupyter-notebook comgt wvdial wpagui
#   libengine-pkcs11-openssl
# Recommended packages:
#   x2gokdriveclient
# The following packages will be REMOVED:
#   fuse
# The following NEW packages will be installed:
#   avahi-daemon bind9-host bind9-libs binfmt-support clang-11 cups-bsd
#   cups-client cups-common fonts-dejavu-core fonts-font-awesome
#   fonts-glyphicons-halflings fonts-lato fonts-lyx
#   fonts-materialdesignicons-webfont fonts-mathjax fonts-roboto-fontface
#   fonts-urw-base35 freeglut3 fuse3 geoclue-2.0 glib-networking
#   glib-networking-common glib-networking-services gsettings-desktop-schemas
#   ieee-data iio-sensor-proxy javascript-common libasound2-plugins
#   libavahi-core7 libavahi-glib1 libc-ares2 libclang-common-11-dev
#   libclang-cpp11 libclang1-11 libdaemon0 libdmlc0 libev4 libevdev2 libffi-dev
#   libfftw3-single3 libfontenc1 libfuse3-3 libglu1-mesa libgudev-1.0-0
#   libhdf5-openmpi-103-1 libhyphen0 libimagequant0 libinput-bin libinput10
#   libjs-angular-file-upload libjs-angular-gettext libjs-angular-schema-form
#   libjs-angularjs libjs-angularjs-smart-table libjs-bootstrap libjs-bootswatch
#   libjs-d3 libjs-jquery-metadata libjs-jquery-tablesorter
#   libjs-jquery.quicksearch libjs-jsencrypt libjs-lrdragndrop
#   libjs-magic-search libjs-mathjax libjs-objectpath libjs-qunit libjs-rickshaw
#   libjs-spin.js libjs-term.js libjs-tv4 libjs-twitter-bootstrap-datepicker
#   libjs-twitter-bootstrap-wizard libjson-glib-1.0-0 libjson-glib-1.0-common
#   liblbfgsb0 libllvm11 liblmdb0 liblzf1 liblzo2-2 libmaxminddb0 libmbim-glib4
#   libmbim-proxy libmd4c0 libmm-glib0 libmtdev1 libnl-genl-3-200 libnotify4
#   libnss-mdns libpfm4 libpocl2 libpocl2-common libproxy1v5 libpulsedsp
#   libqmi-glib5 libqmi-proxy libqt5core5a libqt5dbus5 libqt5designer5
#   libqt5gui5 libqt5help5 libqt5location5 libqt5multimedia5
#   libqt5multimediawidgets5 libqt5network5 libqt5opengl5 libqt5positioning5
#   libqt5positioningquick5 libqt5printsupport5 libqt5qml5 libqt5qmlmodels5
#   libqt5quick5 libqt5quickwidgets5 libqt5sensors5 libqt5serialport5 libqt5sql5
#   libqt5sql5-sqlite libqt5svg5 libqt5test5 libqt5texttospeech5
#   libqt5webchannel5 libqt5webengine-data libqt5webengine5 libqt5webenginecore5
#   libqt5webenginewidgets5 libqt5webkit5 libqt5websockets5 libqt5widgets5
#   libqt5xml5 libqt5xmlpatterns5 libraqm0 libre2-9 libsnapd-glib1 libsoup2.4-1
#   libsoup2.4-common libspeechd2 libspeexdsp1 libsvm3 libtdb1 libtinyxml2.6.2v5
#   libwacom-bin libwacom-common libwacom9 libwebrtc-audio-processing1 libwoff1
#   libwrap0 libxapian30 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcomp3 libxdmf3 libxdo3 libxfont2 libxgboost0 libxkbcommon-x11-0
#   libxkbfile1 libxmlsec1 libxmlsec1-openssl libxmmsclient6 libxrdcl3
#   libxrdcrypto2 libxrdcryptolite2 libxrdutils3 libxrdxml3 libxsimd-dev
#   libxtst6 libz3-4 libz3-dev llvm-11 llvm-11-dev llvm-11-linker-tools
#   llvm-11-runtime llvm-11-tools mailcap mime-support modemmanager numba-doc
#   nxproxy pigz pocl-opencl-icd pulseaudio pulseaudio-utils pymca-data
#   python-babel-localedata python-fisx-common python-mako-doc
#   python-matplotlib-data python-numpy-doc python-odf-doc python-odf-tools
#   python-pyopencl-doc python-tables-data python-xrayutilities-doc
#   python3-appdirs python3-asciitree python3-asgiref python3-asteval
#   python3-attr python3-babel python3-backcall python3-bcrypt python3-beniget
#   python3-blosc python3-bottleneck python3-brotli python3-bs4 python3-certifi
#   python3-cffi python3-cftime python3-chardet python3-click
#   python3-cloudpickle python3-colorama python3-cycler python3-daemon
#   python3-dask python3-dateutil python3-decorator python3-defusedxml
#   python3-distributed python3-django python3-django-haystack python3-doc
#   python3-dropbox python3-elementpath python3-entrypoints python3-et-xmlfile
#   python3-fabio python3-fasteners python3-fisx python3-fonttools python3-fs
#   python3-fsspec python3-fusepy python3-future python3-gast python3-gevent
#   python3-greenlet python3-h5netcdf python3-h5py python3-h5py-serial
#   python3-heapdict python3-html5lib python3-idna python3-iniconfig
#   python3-ipykernel python3-ipython python3-ipython-genutils python3-jdcal
#   python3-jedi python3-jinja2 python3-joblib python3-jupyter-client
#   python3-jupyter-core python3-kiwisolver python3-libarchive-c python3-libsvm
#   python3-llvmlite python3-lmfit python3-locket python3-lockfile python3-lxml
#   python3-lz4 python3-mako python3-markupsafe python3-matplotlib
#   python3-matplotlib-inline python3-mdp python3-mock python3-monotonic
#   python3-mpmath python3-msgpack python3-nacl python3-nest-asyncio
#   python3-netaddr python3-netcdf4 python3-nose python3-numba python3-numcodecs
#   python3-numexpr python3-numpy python3-odf python3-olefile python3-opengl
#   python3-openpyxl python3-packaging python3-pampy python3-pandas
#   python3-pandas-lib python3-paramiko python3-parso python3-partd python3-pbr
#   python3-pexpect python3-pickleshare python3-pil python3-pil.imagetk
#   python3-pip python3-platformdirs python3-pluggy python3-ply python3-pokrok
#   python3-prompt-toolkit python3-psutil python3-ptyprocess python3-py
#   python3-pycparser python3-pygit2 python3-pygments python3-pymca5
#   python3-pyopencl python3-pypdf2 python3-pyqt5 python3-pyqt5.qtmultimedia
#   python3-pyqt5.qtopengl python3-pyqt5.qtpositioning python3-pyqt5.qtquick
#   python3-pyqt5.qtsensors python3-pyqt5.qtserialport python3-pyqt5.qtsql
#   python3-pyqt5.qtsvg python3-pyqt5.qttexttospeech python3-pyqt5.qtwebchannel
#   python3-pyqt5.qtwebengine python3-pyqt5.qtwebkit python3-pyqt5.qtwebsockets
#   python3-pyqt5.qtxmlpatterns python3-pyqt5.sip python3-pytest python3-pythran
#   python3-pytools python3-qtconsole python3-qtpy python3-renderpm
#   python3-reportlab python3-reportlab-accel python3-requests python3-scipy
#   python3-setuptools python3-silx python3-simplejson python3-sklearn
#   python3-sklearn-lib python3-sortedcontainers python3-soupsieve
#   python3-sqlparse python3-stone python3-sympy python3-tables
#   python3-tables-lib python3-tblib python3-threadpoolctl python3-toml
#   python3-toolz python3-tornado python3-traitlets python3-tz python3-ufolib2
#   python3-uncertainties python3-unicodedata2 python3-urllib3 python3-wcwidth
#   python3-webencodings python3-wheel python3-x2go python3-x2gobroker
#   python3-x3dh python3-xapian python3-xapian-haystack python3-xapp
#   python3-xarray python3-xattr python3-xcbgen python3-xcffib
#   python3-xclarityclient python3-xdg python3-xdmf python3-xdo python3-xeddsa
#   python3-xgboost python3-xhtml2pdf python3-xkcd python3-xkit python3-xlib
#   python3-xlrd python3-xlsxwriter python3-xlwt python3-xmlrunner
#   python3-xmlschema python3-xmlsec python3-xmltodict python3-xmmsclient
#   python3-xmodem python3-xopen python3-xphyle python3-xrayutilities
#   python3-xrootd python3-xrstools python3-xsdata python3-xstatic
#   python3-xstatic-angular python3-xstatic-angular-bootstrap
#   python3-xstatic-angular-cookies python3-xstatic-angular-fileupload
#   python3-xstatic-angular-gettext python3-xstatic-angular-lrdragndrop
#   python3-xstatic-angular-mock python3-xstatic-angular-schema-form
#   python3-xstatic-angular-ui-router python3-xstatic-angular-uuid
#   python3-xstatic-angular-vis python3-xstatic-bootstrap-datepicker
#   python3-xstatic-bootstrap-scss python3-xstatic-bootswatch python3-xstatic-d3
#   python3-xstatic-dagre python3-xstatic-dagre-d3 python3-xstatic-filesaver
#   python3-xstatic-font-awesome python3-xstatic-graphlib python3-xstatic-hogan
#   python3-xstatic-jasmine python3-xstatic-jquery
#   python3-xstatic-jquery-migrate python3-xstatic-jquery-ui
#   python3-xstatic-jquery.bootstrap.wizard python3-xstatic-jquery.quicksearch
#   python3-xstatic-jquery.tablesorter python3-xstatic-js-yaml
#   python3-xstatic-jsencrypt python3-xstatic-json2yaml python3-xstatic-lodash
#   python3-xstatic-magic-search python3-xstatic-mdi python3-xstatic-moment
#   python3-xstatic-moment-timezone python3-xstatic-objectpath
#   python3-xstatic-qunit python3-xstatic-rickshaw
#   python3-xstatic-roboto-fontface python3-xstatic-smart-table
#   python3-xstatic-spin python3-xstatic-term.js python3-xstatic-tv4
#   python3-xtermcolor python3-xvfbwrapper python3-yaml python3-zarr
#   python3-zict python3-zmq python3-zope.event python3-zope.interface
#   python3.10-doc qt5-gtk-platformtheme qtspeech5-speechd-plugin
#   qttranslations5-l10n rtkit session-migration sphinx-rtd-theme-common sshfs
#   systemd-hwe-hwdb udev unicode-data usb-modeswitch usb-modeswitch-data
#   wpasupplicant x11-xkb-utils x2gobroker-common xfonts-base xfonts-encodings
#   xfonts-utils xrootd-client-plugins xrootd-plugins xserver-common xvfb
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 480 newly installed, 1 to remove and 48 not upgraded.
# Need to get 376 MB of archives.
# After this operation, 2,442 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-core7 amd64 0.8-5ubuntu5.2 [90.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdaemon0 amd64 0.14-7.1ubuntu3 [14.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblmdb0 amd64 0.9.24-1build2 [47.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmaxminddb0 amd64 1.5.2-1build2 [24.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 bind9-libs amd64 1:9.18.28-0ubuntu0.22.04.1 [1,256 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 bind9-host amd64 1:9.18.28-0ubuntu0.22.04.1 [52.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 avahi-daemon amd64 0.8-5ubuntu5.2 [69.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-lato all 2.0-2.1 [2,696 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.12 [78.2 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.3 [19.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.3 [131 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5positioning5 amd64 5.15.3+dfsg-3 [223 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5printsupport5 amd64 5.15.3+dfsg-2ubuntu0.2 [214 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5qml5 amd64 5.15.3+dfsg-1 [1,472 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5qmlmodels5 amd64 5.15.3+dfsg-1 [205 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5quick5 amd64 5.15.3+dfsg-1 [1,748 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5sensors5 amd64 5.15.3-1 [123 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5webchannel5 amd64 5.15.3-1 [62.9 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwoff1 amd64 1.0.2-1build4 [45.2 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5webkit5 amd64 5.212.0~alpha4-15ubuntu1 [12.8 MB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-single3 amd64 3.3.8-2ubuntu8 [800 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-common all 1.6.6-1build1 [4,432 B]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-0 amd64 1.6.6-1build1 [69.9 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libproxy1v5 amd64 0.4.17-2 [51.9 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-common all 2.72.0-1 [3,718 B]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-services amd64 2.72.0-1 [9,982 B]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking amd64 2.72.0-1 [69.8 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-common all 2.74.2-3ubuntu0.1 [4,070 B]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-1 amd64 2.74.2-3ubuntu0.1 [288 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsnapd-glib1 amd64 1.60-0ubuntu1 [106 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libspeexdsp1 amd64 1.2~rc1.2-1.1ubuntu3 [42.5 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtdb1 amd64 1.4.5-2build1 [46.4 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwebrtc-audio-processing1 amd64 0.3.1-0ubuntu5 [291 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwrap0 amd64 7.6.q-31build2 [47.9 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libasound2-plugins amd64 1.2.6-1 [70.4 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulsedsp amd64 1:15.99.1+dfsg1-1ubuntu2.2 [23.3 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pulseaudio-utils amd64 1:15.99.1+dfsg1-1ubuntu2.2 [76.1 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pulseaudio amd64 1:15.99.1+dfsg1-1ubuntu2.2 [914 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/universe amd64 pigz amd64 2.6-1 [63.6 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-yaml amd64 5.4.1-1ubuntu1 [129 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfuse3-3 amd64 3.10.5-1build1 [81.2 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 fuse3 amd64 3.10.5-1build1 [24.7 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 binfmt-support amd64 2.2.1-2 [55.8 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libllvm11 amd64 1:11.1.0-6 [19.6 MB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libclang-cpp11 amd64 1:11.1.0-6 [10.5 MB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libclang-common-11-dev amd64 1:11.1.0-6 [5,247 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/universe amd64 llvm-11-linker-tools amd64 1:11.1.0-6 [1,275 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libclang1-11 amd64 1:11.1.0-6 [6,053 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/universe amd64 clang-11 amd64 1:11.1.0-6 [75.8 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cups-common all 2.4.1op1-1ubuntu4.11 [253 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cups-client amd64 2.4.1op1-1ubuntu4.11 [127 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-font-awesome all 5.0.10+really4.7.0~dfsg-4.1 [516 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-glyphicons-halflings all 1.009~3.4.1+dfsg-2 [117 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-lyx all 2.3.6-1 [159 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-mathjax all 2.7.9+dfsg-1 [2,208 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-glib1 amd64 0.8-5ubuntu5.2 [8,296 B]
# Get:86 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmm-glib0 amd64 1.20.0-1~ubuntu22.04.4 [262 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnotify4 amd64 0.7.9-3ubuntu5.22.04.1 [20.3 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/main amd64 geoclue-2.0 amd64 2.5.7-3ubuntu3 [111 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/main amd64 ieee-data all 20210605.1 [1,887 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/main amd64 iio-sensor-proxy amd64 3.3-0ubuntu6 [34.4 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/main amd64 javascript-common all 11+nmu1 [5,936 B]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdmlc0 amd64 0.5-1 [193 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhdf5-openmpi-103-1 amd64 1.10.7+repack-4ubuntu2 [1,344 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/main amd64 libimagequant0 amd64 2.17.0-1 [34.6 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjs-angularjs all 1.8.2-2 [552 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjs-bootstrap all 3.4.1+dfsg-2 [124 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjs-d3 all 3.5.17-4 [132 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjs-jquery-metadata all 12-3 [7,096 B]
# Get:100 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjs-jquery-tablesorter all 1:2.31.3+dfsg1-3 [193 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjs-qunit all 1.23.1~dfsg-2 [96.9 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjs-rickshaw all 1.5.1.dfsg-5 [646 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblbfgsb0 amd64 3.0+dfsg.3-10 [29.9 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblzf1 amd64 3.6-3 [7,444 B]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblzo2-2 amd64 2.10-2build3 [53.7 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmbim-glib4 amd64 1.28.0-1~ubuntu20.04.1 [191 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmbim-proxy amd64 1.28.0-1~ubuntu20.04.1 [6,130 B]
# Get:108 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnl-genl-3-200 amd64 3.5.0-0.1 [12.4 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnss-mdns amd64 0.15.1-1ubuntu1 [27.0 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpocl2-common all 1.8-3 [77.1 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpocl2 amd64 1.8-3 [9,405 kB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libqmi-glib5 amd64 1.32.0-1ubuntu0.22.04.1 [772 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libqmi-proxy amd64 1.32.0-1ubuntu0.22.04.1 [6,072 B]
# Get:114 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5xml5 amd64 5.15.3+dfsg-2ubuntu0.2 [124 kB]
# Get:115 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5designer5 amd64 5.15.3-1 [2,832 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5sql5 amd64 5.15.3+dfsg-2ubuntu0.2 [123 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5help5 amd64 5.15.3-1 [162 kB]
# Get:118 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5positioningquick5 amd64 5.15.3+dfsg-3 [45.5 kB]
# Get:119 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5location5 amd64 5.15.3+dfsg-3 [756 kB]
# Get:120 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5multimedia5 amd64 5.15.3-1 [320 kB]
# Get:121 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5multimediawidgets5 amd64 5.15.3-1 [42.6 kB]
# Get:122 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5opengl5 amd64 5.15.3+dfsg-2ubuntu0.2 [153 kB]
# Get:123 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5quickwidgets5 amd64 5.15.3+dfsg-1 [39.9 kB]
# Get:124 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5serialport5 amd64 5.15.3-1 [34.6 kB]
# Get:125 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5sql5-sqlite amd64 5.15.3+dfsg-2ubuntu0.2 [53.0 kB]
# Get:126 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5test5 amd64 5.15.3+dfsg-2ubuntu0.2 [152 kB]
# Get:127 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5texttospeech5 amd64 5.15.3-1 [21.0 kB]
# Get:128 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5webengine-data all 5.15.9+dfsg-1 [8,571 kB]
# Get:129 http://archive.ubuntu.com/ubuntu jammy/main amd64 libre2-9 amd64 20220201+dfsg-1 [160 kB]
# Get:130 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5webenginecore5 amd64 5.15.9+dfsg-1 [41.9 MB]
# Get:131 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5webengine5 amd64 5.15.9+dfsg-1 [176 kB]
# Get:132 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5webenginewidgets5 amd64 5.15.9+dfsg-1 [125 kB]
# Get:133 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5websockets5 amd64 5.15.3-1 [60.4 kB]
# Get:134 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5xmlpatterns5 amd64 5.15.3-1 [901 kB]
# Get:135 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraqm0 amd64 0.7.0-4ubuntu1 [11.7 kB]
# Get:136 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsvm3 amd64 3.24+ds-6 [41.6 kB]
# Get:137 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinyxml2.6.2v5 amd64 2.6.2-6ubuntu0.22.04.1 [33.2 kB]
# Get:138 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:139 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxapian30 amd64 1.4.18-4 [701 kB]
# Get:140 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxcomp3 amd64 2:3.5.99.26-5 [498 kB]
# Get:141 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxdmf3 amd64 3.0+git20190531-10build1 [731 kB]
# Get:142 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:143 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxgboost0 amd64 1.5.2-1 [1,138 kB]
# Get:144 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:145 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1 amd64 1.2.33-1build2 [139 kB]
# Get:146 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1-openssl amd64 1.2.33-1build2 [85.5 kB]
# Get:147 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libxmmsclient6 amd64 0.8+dfsg-22ubuntu0.1 [66.6 kB]
# Get:148 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxrdutils3 amd64 5.4.1-1 [428 kB]
# Get:149 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxrdxml3 amd64 5.4.1-1 [16.7 kB]
# Get:150 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxrdcl3 amd64 5.4.1-1 [575 kB]
# Get:151 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxrdcrypto2 amd64 5.4.1-1 [34.7 kB]
# Get:152 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxrdcryptolite2 amd64 5.4.1-1 [8,312 B]
# Get:153 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxsimd-dev amd64 7.6.0-2 [108 kB]
# Get:154 http://archive.ubuntu.com/ubuntu jammy/universe amd64 llvm-11-runtime amd64 1:11.1.0-6 [186 kB]
# Get:155 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpfm4 amd64 4.11.1+git32-gd0b85fb-1ubuntu0.1 [345 kB]
# Get:156 http://archive.ubuntu.com/ubuntu jammy/universe amd64 llvm-11 amd64 1:11.1.0-6 [9,118 kB]
# Get:157 http://archive.ubuntu.com/ubuntu jammy/main amd64 libffi-dev amd64 3.4.2-4 [63.7 kB]
# Get:158 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-pygments all 2.11.2+dfsg-2ubuntu0.1 [750 kB]
# Get:159 http://archive.ubuntu.com/ubuntu jammy/universe amd64 llvm-11-tools amd64 1:11.1.0-6 [359 kB]
# Get:160 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libz3-4 amd64 4.8.12-1 [5,766 kB]
# Get:161 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libz3-dev amd64 4.8.12-1 [72.2 kB]
# Get:162 http://archive.ubuntu.com/ubuntu jammy/universe amd64 llvm-11-dev amd64 1:11.1.0-6 [29.9 MB]
# Get:163 http://archive.ubuntu.com/ubuntu jammy/main amd64 mailcap all 3.70+nmu1ubuntu1 [23.8 kB]
# Get:164 http://archive.ubuntu.com/ubuntu jammy/main amd64 mime-support all 3.66 [3,696 B]
# Get:165 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 modemmanager amd64 1.20.0-1~ubuntu22.04.4 [1,094 kB]
# Get:166 http://archive.ubuntu.com/ubuntu jammy/main amd64 sphinx-rtd-theme-common all 1.0.0+dfsg-1 [991 kB]
# Get:167 http://archive.ubuntu.com/ubuntu jammy/universe amd64 numba-doc all 0.55.1-0ubuntu2 [737 kB]
# Get:168 http://archive.ubuntu.com/ubuntu jammy/universe amd64 nxproxy amd64 2:3.5.99.26-5 [34.2 kB]
# Get:169 http://archive.ubuntu.com/ubuntu jammy/main amd64 python-babel-localedata all 2.8.0+dfsg.1-7 [4,982 kB]
# Get:170 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python-fisx-common all 1.2.0-2build1 [3,524 kB]
# Get:171 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python-matplotlib-data all 3.5.1-2build1 [2,942 kB]
# Get:172 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python-numpy-doc all 1:1.21.5-1ubuntu22.04.1 [12.1 MB]
# Get:173 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python-odf-doc all 1.4.2-1 [222 kB]
# Get:174 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-defusedxml all 0.7.1-1 [43.2 kB]
# Get:175 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-odf all 1.4.2-1 [79.3 kB]
# Get:176 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python-odf-tools all 1.4.2-1 [27.3 kB]
# Get:177 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python-pyopencl-doc all 2021.2.13-1build1 [266 kB]
# Get:178 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python-tables-data all 3.7.0-2build1 [47.6 kB]
# Get:179 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjs-mathjax all 2.7.9+dfsg-1 [5,665 kB]
# Get:180 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python-xrayutilities-doc all 1.7.3-1build1 [1,079 kB]
# Get:181 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-appdirs all 1.4.4-2 [11.4 kB]
# Get:182 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-asciitree all 0.3.3-3 [5,432 B]
# Get:183 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-asgiref all 3.5.0-1 [23.9 kB]
# Get:184 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-asteval all 0.9.25-2 [17.8 kB]
# Get:185 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-attr all 21.2.0-1 [44.0 kB]
# Get:186 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-tz all 2022.1-1ubuntu0.22.04.1 [30.7 kB]
# Get:187 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-babel all 2.8.0+dfsg.1-7 [85.1 kB]
# Get:188 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-backcall all 0.2.0-2 [11.0 kB]
# Get:189 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-gast all 0.5.2-2 [9,394 B]
# Get:190 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-beniget all 0.4.1-2 [9,904 B]
# Get:191 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-blosc amd64 1.9.2+ds1-3build2 [29.3 kB]
# Get:192 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-numpy amd64 1:1.21.5-1ubuntu22.04.1 [3,467 kB]
# Get:193 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-bottleneck amd64 1.3.2+ds1-2build1 [82.9 kB]
# Get:194 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-brotli amd64 1.0.9-2build6 [319 kB]
# Get:195 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-soupsieve all 2.3.1-1 [33.0 kB]
# Get:196 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-bs4 all 4.10.0-2 [79.1 kB]
# Get:197 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-certifi all 2020.6.20-1 [150 kB]
# Get:198 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-ply all 3.11-5 [47.5 kB]
# Get:199 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-pycparser all 2.21-1 [76.9 kB]
# Get:200 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-cffi all 1.15.0-1build2 [72.6 kB]
# Get:201 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-cftime amd64 1.5.2+ds-1build1 [174 kB]
# Get:202 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-chardet all 4.0.0-1 [98.0 kB]
# Get:203 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-colorama all 0.4.4-1 [24.5 kB]
# Get:204 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-click all 8.0.3-1 [78.3 kB]
# Get:205 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-cloudpickle all 2.0.0-1 [24.5 kB]
# Get:206 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-cycler all 0.11.0-1 [8,156 B]
# Get:207 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-lockfile all 1:0.12.2-2.2 [14.6 kB]
# Get:208 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-daemon all 2.2.4-1.1 [19.6 kB]
# Get:209 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-fsspec all 2022.01.0-1 [96.8 kB]
# Get:210 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-toolz all 0.11.2-1 [44.7 kB]
# Get:211 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-packaging all 21.3-1 [30.7 kB]
# Get:212 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-locket all 0.2.1-1 [5,390 B]
# Get:213 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-partd all 1.2.0-1 [15.8 kB]
# Get:214 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-dask all 2022.01.0+dfsg-1ubuntu1 [724 kB]
# Get:215 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-dateutil all 2.8.1-6 [78.4 kB]
# Get:216 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-decorator all 4.4.2-0ubuntu1 [10.3 kB]
# Get:217 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-markupsafe amd64 2.0.1-2build1 [12.7 kB]
# Get:218 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-jinja2 all 3.0.3-1ubuntu0.2 [108 kB]
# Get:219 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-msgpack amd64 1.0.3-1build1 [67.8 kB]
# Get:220 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-psutil amd64 5.9.0-1build1 [158 kB]
# Get:221 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-sortedcontainers all 2.1.0-2 [27.3 kB]
# Get:222 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-tblib all 1.7.0-2 [12.7 kB]
# Get:223 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-tornado amd64 6.1.0-3build1 [287 kB]
# Get:224 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-heapdict all 1.0.1-1 [5,324 B]
# Get:225 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-zict all 2.0.0-1 [9,440 B]
# Get:226 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-distributed all 2022.01.0+ds.1-1 [575 kB]
# Get:227 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-sqlparse all 0.4.2-1ubuntu0.22.04.2 [31.6 kB]
# Get:228 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-django all 2:3.2.12-2ubuntu1.15 [3,022 kB]
# Get:229 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-django-haystack all 3.1.1-1 [92.4 kB]
# Get:230 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10-doc all 3.10.12-1~22.04.7 [11.0 MB]
# Get:231 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-doc all 3.10.6-1~22.04.1 [7,028 B]
# Get:232 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-idna all 3.3-1ubuntu0.1 [52.1 kB]
# Get:233 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-urllib3 all 1.26.5-1~exp1ubuntu0.2 [98.3 kB]
# Get:234 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-requests all 2.25.1+dfsg-2ubuntu0.1 [48.8 kB]
# Get:235 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-stone all 3.3.1-1 [119 kB]
# Get:236 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-dropbox all 11.26.0-1 [405 kB]
# Get:237 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-elementpath all 2.5.0-1 [123 kB]
# ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up python3-uncertainties (3.1.5-1) ...
# Setting up libdmlc0 (0.5-1) ...
# Setting up python3-xstatic-jasmine (2.4.1.1-4) ...
# Setting up python3-prompt-toolkit (3.0.28-1) ...
# Setting up libjs-angularjs-smart-table (1.4.13-2) ...
# Setting up python3-partd (1.2.0-1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up python3-xstatic-js-yaml (3.8.1.0-1.1) ...
# Setting up python3-sympy (1.9-1) ...
# Setting up glib-networking-services (2.72.0-1) ...
# Setting up libz3-dev:amd64 (4.8.12-1) ...
# Setting up iio-sensor-proxy (3.3-0ubuntu6) ...
# Setting up python3-xstatic-dagre (0.6.4.0-2) ...
# Setting up libjs-twitter-bootstrap-wizard (1.0.0+dfsg1-2.1) ...
# Setting up python-xrayutilities-doc (1.7.3-1build1) ...
# Setting up libxrdcl3:amd64 (5.4.1-1) ...
# Setting up xrootd-client-plugins:amd64 (5.4.1-1) ...
# Setting up llvm-11-runtime (1:11.1.0-6) ...
# Setting up python3-django (2:3.2.12-2ubuntu1.15) ...
# Setting up python3-scipy (1.8.0-1exp2ubuntu1) ...
# Setting up python3-xstatic-magic-search (0.2.5.1-3) ...
# Setting up python3-renderpm:amd64 (3.6.8-1ubuntu0.1) ...
# Setting up libxrdcryptolite2:amd64 (5.4.1-1) ...
# Setting up mime-support (3.66) ...
# Setting up python3-xstatic-d3 (3.5.17.0-4) ...
# Setting up python3-jedi (0.18.0-1) ...
# Setting up bind9-libs:amd64 (1:9.18.28-0ubuntu0.22.04.1) ...
# Setting up libxmlsec1-openssl:amd64 (1.2.33-1build2) ...
# Setting up python3-xstatic-moment-timezone (0.5.22.0-2) ...
# Setting up python3-libsvm (3.24+ds-6) ...
# Setting up python3-babel (2.8.0+dfsg.1-7) ...
# update-alternatives: using /usr/bin/pybabel-python3 to provide /usr/bin/pybabel (pybabel) in auto mode
# Setting up cups-bsd (2.4.1op1-1ubuntu4.11) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up llvm-11-tools (1:11.1.0-6) ...
# Setting up python3-pytest (6.2.5-1ubuntu2) ...
# Setting up python3-tables-lib (3.7.0-2build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up python3-numcodecs (0.9.1+ds-2build1) ...
# Setting up python3-pandas-lib:amd64 (1.3.5+dfsg-3) ...
# Setting up libqt5positioning5:amd64 (5.15.3+dfsg-3) ...
# Setting up python3-cffi (1.15.0-1build2) ...
# Setting up python3-mdp (3.6-1.1) ...
# Setting up python3-xstatic-dagre-d3 (0.4.17.0-2) ...
# Setting up libjs-twitter-bootstrap-datepicker (1.3.1+dfsg1-4.1) ...
# Setting up python-odf-tools (1.4.2-1) ...
# Setting up python3-sklearn-lib:amd64 (0.23.2-5ubuntu6) ...
# Setting up python3-dask (2022.01.0+dfsg-1ubuntu1) ...
# Setting up python3-h5py-serial (3.6.0-2build1) ...
# Setting up python3-xstatic-roboto-fontface (0.5.0.0-4) ...
# Setting up libjs-angular-file-upload (12.2.13+dfsg-2) ...
# Setting up llvm-11 (1:11.1.0-6) ...
# Setting up python3-xstatic-angular-fileupload (12.0.4.0+dfsg1-3) ...
# Setting up libqt5serialport5:amd64 (5.15.3-1) ...
# Setting up libmbim-proxy (1.28.0-1~ubuntu20.04.1) ...
# Setting up python3-xstatic-objectpath (1.2.1.0-4) ...
# Setting up python3-gevent (21.8.0-1build1) ...
# Setting up python3-opengl (3.1.5+dfsg-1) ...
# Setting up python3-xstatic-qunit (1.14.0.2-4) ...
# Setting up python3-xstatic-graphlib (2.1.7.0-2) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libxrdcrypto2:amd64 (5.4.1-1) ...
# Setting up python3-xstatic-bootstrap-scss (3.4.1.0-2) ...
# Setting up python3-xstatic-jquery.bootstrap.wizard (1.0.0.1-3) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up python3-bs4 (4.10.0-2) ...
# Setting up python3-fisx (1.2.0-2build1) ...
# Setting up libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up python3-xstatic-jsencrypt (2.3.1.1-4) ...
# Setting up python3-matplotlib-inline (0.1.3-1) ...
# Setting up python3-fs (2.4.12-1) ...
# Setting up fuse3 (3.10.5-1build1) ...
# Installing new version of config file /etc/fuse.conf ...
# Setting up libclang-cpp11 (1:11.1.0-6) ...
# Setting up libqt5sql5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up wpasupplicant (2:2.10-6ubuntu2.1) ...
# Created symlink /etc/systemd/system/dbus-fi.w1.wpa_supplicant1.service → /lib/systemd/system/wpa_supplicant.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/wpa_supplicant.service → /lib/systemd/system/wpa_supplicant.service.
# Setting up python3-pil:amd64 (9.0.1-1ubuntu0.3) ...
# Setting up python3-llvmlite (0.38.0-1) ...
# Setting up libqt5websockets5:amd64 (5.15.3-1) ...
# Setting up python3-xstatic-jquery-migrate (1.2.1.1+dfsg1-3) ...
# Setting up python3-xstatic-font-awesome (4.7.0.0-5) ...
# Setting up libqt5texttospeech5:amd64 (5.15.3-1) ...
# Setting up libqt5xml5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up python3-jinja2 (3.0.3-1ubuntu0.2) ...
# Setting up python3-distributed (2022.01.0+ds.1-1) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up python3-xstatic-hogan (2.0.0.2-3) ...
# Setting up python3-xopen (1.2.1-4) ...
# Setting up python3-xstatic-mdi (1.6.50.2-2) ...
# Setting up python3-xstatic-filesaver (1.3.2.0-1.1) ...
# Setting up python3-h5netcdf (0.12.0-1) ...
# Setting up python3-pandas (1.3.5+dfsg-3) ...
# Setting up python3-pil.imagetk:amd64 (9.0.1-1ubuntu0.3) ...
# Setting up libqt5qml5:amd64 (5.15.3+dfsg-1) ...
# Setting up libjs-rickshaw (1.5.1.dfsg-5) ...
# Setting up python3-openpyxl (3.0.9-1) ...
# Setting up python3-pexpect (4.8.0-2ubuntu1) ...
# Setting up python3-xstatic-bootswatch (3.3.7.0-4) ...
# Setting up python3-xstatic-moment (2.8.4.2-2) ...
# Setting up python3-requests (2.25.1+dfsg-2ubuntu0.1) ...
# Setting up python3-h5py (3.6.0-2build1) ...
# Setting up python3-bottleneck (1.3.2+ds1-2build1) ...
# Setting up python3-xstatic-jquery.quicksearch (2.0.4.1-3) ...
# Setting up xrootd-plugins:amd64 (5.4.1-1) ...
# Setting up python3-sklearn (0.23.2-5ubuntu6) ...
# Setting up python3-cftime (1.5.2+ds-1build1) ...
# Setting up python3-xstatic-angular-gettext (2.4.1.0-3) ...
# Setting up python3-numexpr (2.8.1-1build1) ...
# Setting up libqt5webchannel5:amd64 (5.15.3-1) ...
# Setting up python3-pytools (2021.2.8-1) ...
# Setting up python3-xcffib (0.11.1-2) ...
# Setting up python3-lmfit (1.0.2-1) ...
# Setting up python3-reportlab (3.6.8-1ubuntu0.1) ...
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up python3-netaddr (0.8.0-2) ...
# Setting up python3-xstatic-angular-lrdragndrop (1.0.2.2-3) ...
# Setting up python3-xstatic-json2yaml (0.1.1.0-1.1) ...
# Setting up python3-xstatic-tv4 (1.2.7.0-4) ...
# Setting up libxdmf3:amd64 (3.0+git20190531-10build1) ...
# Setting up qtspeech5-speechd-plugin:amd64 (5.15.3-1) ...
# Setting up python3-xstatic-term.js (0.0.7.0-4) ...
# Setting up libxgboost0 (1.5.2-1) ...
# Setting up python3-xstatic-lodash (4.16.4.1-2) ...
# Setting up python3-xstatic-angular (1.5.8.0-5) ...
# Setting up python3-jupyter-client (7.1.2-1) ...
# Setting up python3-xeddsa (0.4.6-2build3) ...
# Setting up python3-xstatic-jquery (1.12.4.1-2) ...
# Setting up python3-xstatic-angular-bootstrap (2.5.0.0-2) ...
# Setting up python3-xstatic-spin (1.2.8.0+dfsg1-3) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up numba-doc (0.55.1-0ubuntu2) ...
# Setting up python3-paramiko (2.9.3-0ubuntu1.3) ...
# Setting up python3-xmlsec (1.3.12-1ubuntu0.22.04.1) ...
# Setting up python3-zarr (2.10.3+ds-1) ...
# Setting up bind9-host (1:9.18.28-0ubuntu0.22.04.1) ...
# Setting up clang-11 (1:11.1.0-6) ...
# Setting up python3-x2go (0.6.1.3-2) ...
# /usr/lib/python3/dist-packages/x2go/session.py:2020: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self._SUPPORTED_SOUND and self.terminal_session.params.snd_system is not 'none':
# Setting up python3-django-haystack (3.1.1-1) ...
# Setting up python3-netcdf4 (1.5.8-1build1) ...
# Setting up python3-xrootd (5.4.1-1) ...
# Setting up python3-dropbox (11.26.0-1) ...
# Setting up python3-xstatic-smart-table (1.4.13.2-4) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up python3-x3dh (0.5.8-2) ...
# Setting up libqt5qmlmodels5:amd64 (5.15.3+dfsg-1) ...
# Setting up libqt5sql5-sqlite:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up python3-xstatic-angular-cookies (1.2.24.1-5) ...
# Setting up python3-xstatic-angular-mock (1.2.23.1-7) ...
# Setting up python3-x2gobroker (0.0.4.3-2) ...
# Setting up llvm-11-dev (1:11.1.0-6) ...
# Setting up python3-xstatic-jquery-ui (1.12.0.1+debian+dfsg3-4) ...
# Setting up libqt5xmlpatterns5:amd64 (5.15.3-1) ...
# Setting up python3-xstatic-rickshaw (1.5.0.2-4) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up python3-xstatic-bootstrap-datepicker (0.0.0.1-6.1) ...
# Setting up python3-xarray (0.21.1-1) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up sshfs (3.7.1+repack-2) ...
# Setting up libqmi-glib5:amd64 (1.32.0-1ubuntu0.22.04.1) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up python3-xapian-haystack (2.1.1-1) ...
# Setting up python3-tables (3.7.0-2build1) ...
# Setting up python3-numba (0.55.1-0ubuntu2) ...
# update-alternatives: using /usr/share/python3-numba/numba to provide /usr/bin/numba (numba) in auto mode
# Setting up libqt5help5:amd64 (5.15.3-1) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5multimedia5:amd64 (5.15.3-1) ...
# Setting up python3-xhtml2pdf (0.2.5-1) ...
# Setting up libqt5printsupport5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up python3-xgboost (1.5.2-1) ...
# Setting up python3-xstatic-angular-schema-form (0.8.13.0-4) ...
# Setting up python3-ipython (7.31.1-1) ...
# Setting up python3-ipykernel (6.7.0-1) ...
# Setting up libqt5multimediawidgets5:amd64 (5.15.3-1) ...
# Setting up python3-xvfbwrapper (0.2.9-2) ...
# Setting up python3-xdmf (3.0+git20190531-10build1) ...
# Setting up avahi-daemon (0.8-5ubuntu5.2) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of force-reload.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Created symlink /etc/systemd/system/dbus-org.freedesktop.Avahi.service → /lib/systemd/system/avahi-daemon.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/avahi-daemon.service → /lib/systemd/system/avahi-daemon.service.
# Created symlink /etc/systemd/system/sockets.target.wants/avahi-daemon.socket → /lib/systemd/system/avahi-daemon.socket.
# Setting up libqt5opengl5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libpocl2:amd64 (1.8-3) ...
# Setting up libqt5quick5:amd64 (5.15.3+dfsg-1) ...
# Setting up libqt5positioningquick5:amd64 (5.15.3+dfsg-3) ...
# Setting up libqt5designer5:amd64 (5.15.3-1) ...
# Setting up libqt5location5:amd64 (5.15.3+dfsg-3) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Setting up libqmi-proxy (1.32.0-1ubuntu0.22.04.1) ...
# Setting up libqt5webkit5:amd64 (5.212.0~alpha4-15ubuntu1) ...
# Setting up libqt5quickwidgets5:amd64 (5.15.3+dfsg-1) ...
# Setting up pocl-opencl-icd:amd64 (1.8-3) ...
# Setting up libqt5webenginecore5:amd64 (5.15.9+dfsg-1) ...
# Setting up modemmanager (1.20.0-1~ubuntu22.04.4) ...
# Created symlink /etc/systemd/system/dbus-org.freedesktop.ModemManager1.service → /lib/systemd/system/ModemManager.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/ModemManager.service → /lib/systemd/system/ModemManager.service.
# Setting up python3-pyopencl (2021.2.13-1build1) ...
# Setting up python3-pyqt5 (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qtpositioning (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qtsvg (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qttexttospeech (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qtsql (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qtopengl (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qtmultimedia (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qtxmlpatterns (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qtsensors (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qtwebsockets (5.15.6+dfsg-1ubuntu3) ...
# Setting up libqt5webengine5:amd64 (5.15.9+dfsg-1) ...
# Setting up python3-pyqt5.qtserialport (5.15.6+dfsg-1ubuntu3) ...
# Setting up libqt5webenginewidgets5:amd64 (5.15.9+dfsg-1) ...
# Setting up python3-pyqt5.qtwebchannel (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qtwebkit (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-pyqt5.qtwebengine (5.15.5-1) ...
# Setting up python3-pyqt5.qtquick (5.15.6+dfsg-1ubuntu3) ...
# Setting up python3-qtpy (2.0.0-3) ...
# Setting up python3-qtconsole (5.2.2-1) ...
# Setting up python3-ufolib2 (0.13.1+dfsg1-1) ...
# Setting up python3-fonttools (4.29.1-2build1) ...
# Setting up python3-matplotlib (3.5.1-2build1) ...
# Setting up python3-xrayutilities (1.7.3-1build1) ...
# Setting up python3-pymca5 (5.7.1+dfsg-1build1) ...
# Setting up python3-fabio (0.13.0+dfsg-1build1) ...
# Setting up python3-silx (1.0.0+dfsg-4) ...
# Setting up python3-xrstools (0.15.0+git20210910+c147919d-2build1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.4) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Setting up glib-networking:amd64 (2.72.0-1) ...
# Setting up libsoup2.4-1:amd64 (2.74.2-3ubuntu0.1) ...
# Setting up geoclue-2.0 (2.5.7-3ubuntu3) ...
# Setting up libsnapd-glib1:amd64 (1.60-0ubuntu1) ...
# Setting up pulseaudio (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Adding user pulse to group audio
# Failed to send reload request: No such file or directory
# Created symlink /etc/systemd/user/default.target.wants/pulseaudio.service → /usr/lib/systemd/user/pulseaudio.service.
# Created symlink /etc/systemd/user/sockets.target.wants/pulseaudio.socket → /usr/lib/systemd/user/pulseaudio.socket.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...

# %%
from langchain.llms import
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-41-f5e4b863fea7> in <cell line: 1>()
# ----> 1 from langchain.llms import GoogleGeminiFlash
#       2 from langchain.prompts import PromptTemplate
#       3 from langchain.chains import LLMChain
#
# ImportError: cannot import name 'GoogleGeminiFlash' from 'langchain.llms' (/usr/local/lib/python3.10/dist-packages/langchain/llms/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from langchain.llms import VertexAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# Configure the Gemini Flash model
llm = GoogleGeminiFlash(
    api_key="your_gemini_api_key_here",
    model="gemini-flash",
    temperature=0.7  # Adjust for creativity
)

# Create a prompt template
prompt_template = PromptTemplate(
    input_variables=["question"],
    template="You are a helpful assistant. Answer the following question:\n\n{question}"
)

# Create the LLM chain
chain = LLMChain(llm=llm, prompt=prompt_template)

# Run the chain with a sample question
question = "What is LangChain?"
response = chain.run({"question": question})

print("Answer:", response)
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# <ipython-input-39-f889dc4a6246> in <cell line: 6>()
#       4
#       5 # Configure the Gemini Flash model
# ----> 6 llm = VertexAI(
#       7     api_key="GOOGLE_API_KEY",
#       8     model="gemini-flash",
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warn_if_direct_instance(self, *args, **kwargs)
#     214                         warned = True
#     215                         emit_warning()
# --> 216                     return wrapped(self, *args, **kwargs)
#     217
#     218                 obj.__init__ = functools.wraps(obj.__init__)(  # type: ignore[misc]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     123     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     124         """"""
# --> 125         super().__init__(*args, **kwargs)
#     126
#     127     @classmethod
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_mock_val_ser.py in __getattr__(self, item)
#      98         # raise an AttributeError if `item` doesn't exist
#      99         getattr(self._val_or_ser, item)
# --> 100         raise PydanticUserError(self._error_message, code=self._code)
#     101
#     102     def rebuild(self) -> ValSer | None:
#
# PydanticUserError: `VertexAI` is not fully defined; you should define `_LanguageModel`, then call `VertexAI.model_rebuild()`.
#
# For further information visit https://errors.pydantic.dev/2.10/u/class-not-fully-defined
